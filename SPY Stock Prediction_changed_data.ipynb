# %% [markdown]
# # Data Preparation

# %%
# Read the data set

# %%
import pandas as pd                                                          # importing pandas library
import matplotlib.pyplot as plt                                              # import matplotlib library for plotting 
import numpy as np                                                                            
import seaborn as sns                                                        # importing seaborn library
SPY_df = pd.read_csv('new_spy2.csv')                                          # Reading csv file as new_spy2.csv
print(SPY_df)                                                                 # print the data from the data file
# Out:
#             Date       Close     Volume  Day  Week  Weekday  Difference Result
# 0     29/01/1993   25.218233    1003200   29     4        4    0.179358     Up
# 1     01/02/1993   25.397591     480500    1     5        0    0.053806     Up
# 2     02/02/1993   25.451397     201300    2     5        1    0.269035     Up
# 3     03/02/1993   25.720432     529400    3     5        2    0.107616     Up
# 4     04/02/1993   25.828049     531500    4     5        3   -0.017920   Down
# ...          ...         ...        ...  ...   ...      ...         ...    ...
# 7555  31/01/2023  406.480011   86811800   31     5        1    4.319977     Up
# 7556  01/02/2023  410.799988  101459200    1     5        2    5.980011     Up
# 7557  02/02/2023  416.779999  101654500    2     5        3   -4.429993   Down
# 7558  03/02/2023  412.350006   94647400    3     5        4   -2.520020   Down
# 7559  06/02/2023  409.829987   60295300    6     6        0 -409.829987   Down
#
# [7560 rows x 8 columns]

# %% [markdown]
# # Print the head

# %%
SPY_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7560 entries, 0 to 7559
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        7560 non-null   object
#  1   Close       7560 non-null   float64
#  2   Volume      7560 non-null   int64
#  3   Day         7560 non-null   int64
#  4   Week        7560 non-null   int64
#  5   Weekday     7560 non-null   int64
#  6   Difference  7560 non-null   float64
#  7   Result      7560 non-null   object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 472.6+ KB

# %% [markdown]
# # Check for missing values

# %%
# Check any missing values
import pandas as pd                        
SPY_df = pd.read_csv('new_spy2.csv')  
SPY_df.isnull().sum()
# Out:
# Date          0
# Close         0
# Volume        0
# Day           0
# Week          0
# Weekday       0
# Difference    0
# Result        0
# dtype: int64

# %% [markdown]
# # Data Types

# %%
SPY_df.dtypes    # Check the data types of the dataset using dtypes function
# Out:
# Date           object
# Close         float64
# Volume          int64
# Day             int64
# Week            int64
# Weekday         int64
# Difference    float64
# Result         object
# dtype: object

# %% [markdown]
# # Central Tendency of the Data Set

# %%
# To find the mean, mode and median for the data set 

import pandas as pd                                                           # importing pandas library
import matplotlib.pyplot as plt                                               # importing matplotlib library for plotting 
import numpy as np                                                            # importing numpy library  
import seaborn as sns                                                         # importing seaborn library
SPY_df = pd.read_csv('new_spy2.csv')                                            # Reading csv file as new_spy2.csv
SPY_df.describe()                                                              # Finding the central tendencies for the data
# Out:
#              Close        Volume          Day         Week      Weekday  \
# count  7560.000000  7.560000e+03  7560.000000  7560.000000  7560.000000
# mean    135.569118  8.454954e+07    15.727646    26.612434     2.020899
# std     104.041429  9.362478e+07     8.756743    14.970432     1.399766
# min      24.913317  5.200000e+03     1.000000     1.000000     0.000000
# 25%      70.946917  9.191775e+06     8.000000    14.000000     1.000000
# 50%      93.737816  6.177445e+07    16.000000    27.000000     2.000000
# 75%     179.777882  1.180260e+08    23.000000    40.000000     3.000000
# max     470.083679  8.710263e+08    31.000000    53.000000     4.000000
#
#         Difference
# count  7560.000000
# mean     -0.003336
# std       5.123856
# min    -409.829987
# 25%      -0.461224
# 50%       0.054528
# 75%       0.617663
# max      20.466003

# %% [markdown]
# # Data Visualization using Scatter Plot

# %%
# scatter plot matrix to examine the correlation between each of the measurements. 
from pandas.plotting import scatter_matrix                  # import pandas library to plot and scatar matrix
features = ['Date', 'Close', 'Volume', 'Day', 'Week', 'Weekday','Difference']
scatter_matrix(SPY_df[features], figsize=(30,30))
# Out:
# array([[<AxesSubplot:xlabel='Close', ylabel='Close'>,
#         <AxesSubplot:xlabel='Volume', ylabel='Close'>,
#         <AxesSubplot:xlabel='Day', ylabel='Close'>,
#         <AxesSubplot:xlabel='Week', ylabel='Close'>,
#         <AxesSubplot:xlabel='Weekday', ylabel='Close'>,
#         <AxesSubplot:xlabel='Difference', ylabel='Close'>],
#        [<AxesSubplot:xlabel='Close', ylabel='Volume'>,
#         <AxesSubplot:xlabel='Volume', ylabel='Volume'>,
#         <AxesSubplot:xlabel='Day', ylabel='Volume'>,
#         <AxesSubplot:xlabel='Week', ylabel='Volume'>,
#         <AxesSubplot:xlabel='Weekday', ylabel='Volume'>,
#         <AxesSubplot:xlabel='Difference', ylabel='Volume'>],
#        [<AxesSubplot:xlabel='Close', ylabel='Day'>,
#         <AxesSubplot:xlabel='Volume', ylabel='Day'>,
#         <AxesSubplot:xlabel='Day', ylabel='Day'>,
#         <AxesSubplot:xlabel='Week', ylabel='Day'>,
#         <AxesSubplot:xlabel='Weekday', ylabel='Day'>,
# ...

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# # Find the Co-Relation between variables

# %%
import pandas as pd                        #                  
SPY_df = pd.read_csv('new_spy2.csv')       #
SPY_df.corr()                              #
# Out:
#                Close    Volume       Day      Week   Weekday  Difference
# Close       1.000000  0.112859 -0.000089  0.015884  0.001545   -0.023855
# Volume      0.112859  1.000000 -0.011632 -0.005251  0.049842    0.004085
# Day        -0.000089 -0.011632  1.000000  0.065804 -0.000550    0.014318
# Week        0.015884 -0.005251  0.065804  1.000000 -0.016217    0.017244
# Weekday     0.001545  0.049842 -0.000550 -0.016217  1.000000    0.008363
# Difference -0.023855  0.004085  0.014318  0.017244  0.008363    1.000000

# %% [markdown]
# # Heatmap for the dataset

# %%
import matplotlib.pyplot as plt    # importing matplotlib function as plt to make different plots  to analyze the  
import seaborn as sns              #                                  
import pandas as pd                #
SPY_df = pd.read_csv('new_spy2.csv') #
plt.figure(figsize=(12,8))          #
sns.heatmap(SPY_df.corr(), cmap='Wistia', annot=True, fmt='.1f', linewidths=.1) #
plt.show()                         #

# %%
# data normalization
from pandas import Series
from sklearn.preprocessing import MinMaxScaler
# define contrived series
data = SPY_df['Close']

series = Series(data)
print(series)
# prepare data for normalization
values = series.values
values = values.reshape((len(values), 1))
# train the normalization
scaler = MinMaxScaler(feature_range=(0, 1))
scaler = scaler.fit(values)
print('Min: %f, Max: %f' % (scaler.data_min_, scaler.data_max_))
# normalize the dataset and print
normalized = scaler.transform(values)
print(normalized)
# Out:
# 0        25.218233
# 1        25.397591
# 2        25.451397
# 3        25.720432
# 4        25.828049
#            ...
# 7555    406.480011
# 7556    410.799988
# 7557    416.779999
# 7558    412.350006
# 7559    409.829987
# Name: Close, Length: 7560, dtype: float64
# Min: 24.913317, Max: 470.083679
# [[6.84943127e-04]
#  [1.08783951e-03]
#  [1.20870627e-03]
#  ...
#  [8.80262289e-01]
#  [8.70311058e-01]
#  [8.64650260e-01]]

# %%
# data normalization
from pandas import Series
from sklearn.preprocessing import MinMaxScaler
# define contrived series
data = SPY_df['Week']

series = Series(data)
print(series)
# prepare data for normalization
values = series.values
values = values.reshape((len(values), 1))
# train the normalization
scaler = MinMaxScaler(feature_range=(0, 1))
scaler = scaler.fit(values)
print('Min: %f, Max: %f' % (scaler.data_min_, scaler.data_max_))
# normalize the dataset and print
normalized = scaler.transform(values)
print(normalized)
# Out:
# 0       4
# 1       5
# 2       5
# 3       5
# 4       5
#        ..
# 7555    5
# 7556    5
# 7557    5
# 7558    5
# 7559    6
# Name: Week, Length: 7560, dtype: int64
# Min: 1.000000, Max: 53.000000
# [[0.05769231]
#  [0.07692308]
#  [0.07692308]
#  ...
#  [0.07692308]
#  [0.07692308]
#  [0.09615385]]

# %%
# data normalization
from pandas import Series
from sklearn.preprocessing import MinMaxScaler
# define contrived series
data = SPY_df['Weekday']

series = Series(data)
print(series)
# prepare data for normalization
values = series.values
values = values.reshape((len(values), 1))
# train the normalization
scaler = MinMaxScaler(feature_range=(0, 1))
scaler = scaler.fit(values)
print('Min: %f, Max: %f' % (scaler.data_min_, scaler.data_max_))
# normalize the dataset and print
normalized = scaler.transform(values)
print(normalized)
# Out:
# 0       4
# 1       0
# 2       1
# 3       2
# 4       3
#        ..
# 7555    1
# 7556    2
# 7557    3
# 7558    4
# 7559    0
# Name: Weekday, Length: 7560, dtype: int64
# Min: 0.000000, Max: 4.000000
# [[1.  ]
#  [0.  ]
#  [0.25]
#  ...
#  [0.75]
#  [1.  ]
#  [0.  ]]

# %%
# data normalization
from pandas import Series
from sklearn.preprocessing import MinMaxScaler
# define contrived series
data = SPY_df['Volume']

series = Series(data)
print(series)
# prepare data for normalization
values = series.values
values = values.reshape((len(values), 1))
# train the normalization
scaler = MinMaxScaler(feature_range=(0, 1))
scaler = scaler.fit(values)
print('Min: %f, Max: %f' % (scaler.data_min_, scaler.data_max_))
# normalize the dataset and print
normalized = scaler.transform(values)
print(normalized)
# Out:
# 0         1003200
# 1          480500
# 2          201300
# 3          529400
# 4          531500
#           ...
# 7555     86811800
# 7556    101459200
# 7557    101654500
# 7558     94647400
# 7559     60295300
# Name: Volume, Length: 7560, dtype: int64
# Min: 5200.000000, Max: 871026300.000000
# [[0.00114578]
#  [0.00054568]
#  [0.00022514]
#  ...
#  [0.11670131]
#  [0.10865661]
#  [0.06921773]]

# %%
import pandas as pd  
SPYdf = pd.read_csv('new_spy2.csv')
SPYdf['Date'] = pd.to_datetime(SPYdf.Date,infer_datetime_format=True)
print(SPYdf)
# Out:
#            Date       Close     Volume  Day  Week  Weekday  Difference Result
# 0    1993-01-29   25.218233    1003200   29     4        4    0.179358     Up
# 1    1993-02-01   25.397591     480500    1     5        0    0.053806     Up
# 2    1993-02-02   25.451397     201300    2     5        1    0.269035     Up
# 3    1993-02-03   25.720432     529400    3     5        2    0.107616     Up
# 4    1993-02-04   25.828049     531500    4     5        3   -0.017920   Down
# ...         ...         ...        ...  ...   ...      ...         ...    ...
# 7555 2023-01-31  406.480011   86811800   31     5        1    4.319977     Up
# 7556 2023-02-01  410.799988  101459200    1     5        2    5.980011     Up
# 7557 2023-02-02  416.779999  101654500    2     5        3   -4.429993   Down
# 7558 2023-02-03  412.350006   94647400    3     5        4   -2.520020   Down
# 7559 2023-02-06  409.829987   60295300    6     6        0 -409.829987   Down
#
# [7560 rows x 8 columns]

# %%
x = SPYdf.loc[0:7400,["Volume","Week","Weekday"]]
print("x=",x)
y = SPYdf.loc[0:7400,'Close']
print("y=",y)
# Out:
# x=          Volume  Week  Weekday
# 0       1003200     4        4
# 1        480500     5        0
# 2        201300     5        1
# 3        529400     5        2
# 4        531500     5        3
# ...         ...   ...      ...
# 7396  170004900    24        0
# 7397  104011800    24        1
# 7398  125666800    24        2
# 7399  134473300    24        3
# 7400  111113900    24        4
#
# [7401 rows x 3 columns]
# y= 0        25.218233
# 1        25.397591
# 2        25.451397
# 3        25.720432
# 4        25.828049
#            ...
# 7396    370.159790
# 7397    369.044373
# 7398    374.305572
# 7399    361.917542
# 7400    362.697754
# Name: Close, Length: 7401, dtype: float64

# %%
x.shape
# Out:
# (7401, 3)

# %%
y.shape
# Out:
# (7401,)

# %%
from sklearn.model_selection import train_test_split                      
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20,  random_state=10)
print("input Training set=",x_train)

print("input test set =",x_test)

print("output training set=",y_train)

print("output test set=",y_test)
# Out:
# input Training set=          Volume  Week  Weekday
# 2288   23755400     9        3
# 1174    3259000    39        0
# 1164     803500    37        0
# 1572    6897400    16        3
# 250      310400     4        1
# ...         ...   ...      ...
# 3441   73962700    39        1
# 1344   10202600    22        2
# 4623  161660500    23        1
# 7293   91173100     2        3
# 1289    3362800    11        0
#
# [5920 rows x 3 columns]
# input test set =          Volume  Week  Weekday
# 3482   45505300    47        2
# 5136  271956800    25        4
# 3938  624095600    38        2
# 3094   91647400    19        2
# 6131   44698800    23        0
# ...         ...   ...      ...
# 21       182400     9        1
# 2949   54212600    42        2
# 3641   98378700    29        0
# 2309   17711000    14        0
# 5180   90888900    34        4
#
# [1481 rows x 3 columns]
# output training set= 2288     74.546730
# 1174     60.922062
# 1164     59.419136
# 1572     88.490982
# ...

# %%
from sklearn.preprocessing import StandardScaler              

scale = StandardScaler()

x_train = scale.fit_transform(x_train)
print(x_train)

x_test = scale.transform(x_test)
print(x_test)
# Out:
# [[-0.65166449 -1.15300035  0.69303383]
#  [-0.86904042  0.84542706 -1.45014584]
#  [-0.89508239  0.71219857 -1.45014584]
#  ...
#  [ 0.81089722 -0.22040089 -0.73575262]
#  [ 0.06333841 -1.61930008  0.69303383]
#  [-0.86793957 -1.01977185 -1.45014584]]
# [[-0.42099448  1.37834104 -0.02135939]
#  [ 1.98065196 -0.08717239  1.40742705]
#  [ 5.71528342  0.77881282 -0.02135939]
#  ...
#  [ 0.13975788  0.17928459 -1.45014584]
#  [-0.71576878 -0.81992911 -1.45014584]
#  [ 0.06032431  0.51235583  1.40742705]]

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=100, random_state=10, min_samples_split=2, min_samples_leaf=1, max_depth=10, bootstrap=True)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

df=pd.DataFrame({'Actual':y_test, 'Predicted':y_pred})
df
# Out:
#           Actual   Predicted
# 3482  102.499832  183.833884
# 5136  133.403183   97.836911
# 3938   87.730835   90.355076
# 3094   83.059898  210.022412
# 6131  220.699204  246.945683
# ...          ...         ...
# 21     25.792179   28.517053
# 2949   78.110939  190.102056
# 3641  114.184151  196.752202
# 2309   77.060585   77.975427
# 5180  139.734940  208.838971
#
# [1481 rows x 2 columns]

# %%
from sklearn import metrics
import numpy as np 
print("Mean Absolute Error:", round(metrics.mean_absolute_error(y_test, y_pred), 4))
print("Mean Squared Error:", round(metrics.mean_squared_error(y_test, y_pred), 4))
print("Root Mean Squared Error:", round(np.sqrt(metrics.mean_squared_error(y_test, y_pred)), 4))
print("(R^2) Score:", round(metrics.r2_score(y_test, y_pred), 4))
print(f'Train Score : {model.score(x_train, y_train) * 100:.2f}% and Test Score : {model.score(x_test, y_test) * 100:.2f}% using Random Tree Regressor.')
errors = abs(y_pred - y_test)
mape = 100 * (errors / y_test)
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Mean Absolute Error: 47.7244
# Mean Squared Error: 5645.2361
# Root Mean Squared Error: 75.1348
# (R^2) Score: 0.3983
# Train Score : 55.36% and Test Score : 39.83% using Random Tree Regressor.
# Accuracy: 63.55 %.

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
plt.figure(figsize=(15,10))
plt.title('SPY prediction')   
plt.xlabel('Date')  
plt.ylabel('Close')   
plt.plot(y_test[:31], label ='Actual' )  
 
plt.grid()  

plt.show()
